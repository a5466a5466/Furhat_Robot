# %% [markdown]
# # IIS Assignment 2
# ### Student: Sheng-Yu Wu

# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
data = pd.read_csv("dataset.csv")

labels = data["emotion"]
inputs = data.drop("emotion", axis=1)

# %% [markdown]
# ### Split Data
# •	Train/val/test : 70/20/10

# %%
from sklearn.model_selection import train_test_split


# split = 70/20/10
data_in, test_in, data_out, test_out = train_test_split(
    inputs,
    labels,
    test_size=0.1,
    random_state=42,
    stratify=labels
)

train_in, val_in, train_out, val_out = train_test_split(
    data_in,
    data_out,
    test_size=(0.2/0.9),  # 20% of the original data
    random_state=42,
    stratify=data_out
)

print("\nLenght of each split of the data: ", len(train_in), len(val_in), len(test_in), "\n")
# Out:
# Lenght of each split of the data:  811 233 117
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %% [markdown]
# ### Normalization

# %%
from sklearn import preprocessing

normalized_train_in = preprocessing.scale(train_in)
normalized_val_in = preprocessing.scale(val_in)
# Out:
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %% [markdown]
# ## Chosing Model

# %%
from sklearn.metrics import accuracy_score

# %%
def train_model(model, train_in = train_in, train_out = train_out):
    model.fit(train_in, train_out)

def eval_model(model, val_in = val_in, val_out=val_out):
    predicted_val = model.predict(val_in)
    return accuracy_score(predicted_val, val_out)

# %% [markdown]
# ### SGDClassifier

# %%
from sklearn.linear_model import SGDClassifier

SGDClassifier_Model = SGDClassifier()

train_model(SGDClassifier_Model)
print("SGDClassifier_Model accuracy_score: ", eval_model(SGDClassifier_Model))
# Out:
# SGDClassifier_Model accuracy_score:  0.5708154506437768
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# ...

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC

SVC_model = SVC()
train_model(SVC_model)
print("SVC accuracy_score: ", eval_model(SVC_model))
# Out:
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %% [markdown]
# ### KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
train_model(knn)
print("KNeighborsClassifier accuracy_score: ", eval_model(knn))
# Out:
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %% [markdown]
# ## Try Normalized Data

# %% [markdown]
# ### N_SGDClassifier

# %%
SGDClassifier_Model = SGDClassifier()

train_model(SGDClassifier_Model, normalized_train_in)
print("SGDClassifier_Model accuracy_score: ", eval_model(SGDClassifier_Model, normalized_val_in))
# Out:
# SGDClassifier_Model accuracy_score:  0.575107296137339
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %% [markdown]
# ### N_SVC

# %%
N_SVC = SVC()
train_model(N_SVC, train_in=normalized_train_in)
eval_model(N_SVC, val_in=normalized_val_in)
# Out:
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %% [markdown]
# ### N_KNeighborsClassifier

# %%
N_knn = KNeighborsClassifier()
train_model(N_knn, train_in=normalized_train_in)
eval_model(N_knn, val_in=normalized_val_in)
# Out:
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %% [markdown]
# ### N GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

N_GaussianNB = GaussianNB()
train_model(N_GaussianNB, train_in=normalized_train_in)
eval_model(N_GaussianNB, val_in=normalized_val_in)
# Out:
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %% [markdown]
# # Hyperparameter searching/tuning

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### SGDClassifier tuning

# %%
SGD_param_grid = [
    {"loss": ['hinge', 'log_loss', 'loss', 'squared_error'], "penalty" : ['l2', 'l1']}
]
best_SGD = GridSearchCV(SGDClassifier(), SGD_param_grid)
train_model(best_SGD, normalized_train_in)
eval_model(best_SGD, normalized_val_in)
# Out:
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %%
print(
    "Best parameters of SVC model: ",
    best_SGD.best_params_
)
# Out:
# Best parameters of SVC model:  {'loss': 'log_loss', 'penalty': 'l1'}

# %% [markdown]
# ### Tuing KNeighborsClassifier

# %%
Knn_param_grid = [
    {"algorithm": ['auto', 'ball_tree', 'kd_tree', 'brute'], "n_neighbors": [1, 5, 10, 25, 50]}
]

best_knn = GridSearchCV(KNeighborsClassifier(), Knn_param_grid)
best_knn.fit(normalized_train_in, train_out)
eval_model(best_knn, normalized_val_in)
# Out:
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %%
print(
    "Best parameters of SVC model: ",
    best_knn.best_params_
)
# Out:
# Best parameters of SVC model:  {'algorithm': 'auto', 'n_neighbors': 50}

# %% [markdown]
# ### Tuning SVC

# %%
SVC_param_grid = [
    {"kernel": ["rbf", "linear", "sigmoid"], "degree": [3, 10, 25, 50], "gamma":["scale", "auto"]}
]

best_SVC = GridSearchCV(SVC(), SVC_param_grid)
best_SVC.fit(normalized_train_in, train_out)
eval_model(best_SVC, normalized_val_in)
# Out:
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %%
print("Best parameters of SVC model: ",
    best_SVC.best_params_)
# Out:
# Best parameters of SVC model:  {'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}

# %% [markdown]
# ### Tuning GaussianNB
# Nope

# %% [markdown]
# # Loading Testing Data
# ## Using best_SVC model

# %%
test_data = pd.read_csv("test_to_submit.csv")
normalized_test_data = preprocessing.scale(test_data)
normalized_test_data
# Out:
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# array([[ 0.54373835,  1.55077311, -0.61395915, ..., -0.89075255,
#         -0.67003779,  0.13219195],
#        [ 0.58344813,  0.83043412, -0.52876919, ...,  3.16924017,
# ...

# %%
predicted_test_data = best_SVC.predict(test_data)
print(predicted_test_data)
# Out:
# ['happy' 'angry' 'happy' 'neutral' 'angry' 'neutral' 'happy' 'angry'
#  'happy' 'happy' 'happy' 'happy' 'neutral' 'angry' 'happy' 'happy'
#  'neutral' 'happy' 'happy' 'happy' 'happy' 'neutral' 'angry' 'angry'
#  'happy' 'neutral' 'angry' 'angry' 'neutral' 'neutral' 'happy' 'happy'
#  'neutral' 'neutral' 'happy' 'happy' 'neutral' 'happy' 'happy' 'angry'
#  'neutral' 'happy' 'neutral' 'happy' 'happy' 'neutral' 'neutral' 'neutral'
#  'angry' 'neutral' 'happy' 'angry' 'neutral' 'neutral' 'neutral' 'happy'
#  'angry' 'happy' 'happy' 'neutral' 'happy' 'happy' 'happy' 'angry' 'happy'
#  'neutral' 'happy' 'neutral' 'neutral' 'neutral' 'angry' 'happy' 'neutral'
#  'angry' 'angry' 'happy' 'happy' 'neutral' 'neutral' 'happy' 'angry'
#  'neutral' 'happy' 'happy' 'happy' 'angry' 'neutral' 'happy' 'happy'
#  'happy' 'happy' 'neutral' 'happy' 'neutral' 'happy' 'angry' 'angry'
#  'neutral' 'happy' 'happy' 'happy' 'happy' 'happy' 'neutral' 'angry'
# ...

# %% [markdown]
# ### N_SVC

# %%
type(predicted_test_data)
predicted_test_data.shape
# Out:
# (122,)

# %%
import numpy as np

np.savetxt("output", predicted_test_data, fmt='%s')

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(best_SVC, normalized_train_in, train_out, scoring='accuracy', cv=10)
scores
# Out:
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\a5466\anaconda3\envs\IIS\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...
